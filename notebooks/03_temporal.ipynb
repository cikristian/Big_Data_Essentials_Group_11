# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, when, to_date, date_format, hour, month, dayofweek

spark = SparkSession.builder \
    .appName("RRSIS") \
    .master("local[*]") \
    .getOrCreate()

df = spark.read.csv(
    "hdfs://localhost:9000/rrsis/data/Road Accident Data.csv",
    header=True,
    inferSchema=True
)
df = df.withColumn("Time", col("Time").cast("string"))

df_clean = df.withColumn("Accident_Date_Parsed", to_date(col("Accident Date"), "M/d/yyyy"))
df_clean = df_clean.withColumn("Time_of_Day", date_format(col("Time"), "HH:mm:ss"))
df_clean = df_clean.dropDuplicates()
df_clean = df_clean.filter(col("Time").isNotNull())

for c in ["Road_Surface_Conditions", "Road_Type", "Weather_Conditions"]:
    df_clean = df_clean.withColumn(
        c,
        when((col(c).isNull()) | (col(c) == ""), "Unknown").otherwise(col(c))
    )

df_accidents = df_clean.dropDuplicates(["Accident_Index"])
print("Accident-level rows:", df_accidents.count())
# Out:
# Accident-level rows: 197644

# %%
df_time = df_accidents.withColumn("Hour", hour(col("Time_of_Day")))
df_time = df_time.withColumn("Month_Num", month(col("Accident_Date_Parsed")))
df_time = df_time.withColumn(
    "Weekend_Flag",
    when(col("Day_of_Week").isin("Saturday", "Sunday"), "Weekend").otherwise("Weekday")
)
df_time.select("Accident_Date_Parsed", "Time_of_Day", "Hour", "Day_of_Week", "Month", "Weekend_Flag").show(10)
# Out:
# +--------------------+-----------+----+-----------+-----+------------+
# |Accident_Date_Parsed|Time_of_Day|Hour|Day_of_Week|Month|Weekend_Flag|
# +--------------------+-----------+----+-----------+-----+------------+
# |          2022-01-05|   12:15:00|  12|    Tuesday|  Jan|     Weekday|
# |          2021-03-18|   07:38:00|   7|  Wednesday|  Mar|     Weekday|
# |          2021-03-19|   19:13:00|  19|   Thursday|  Mar|     Weekday|
# |          2021-04-13|   16:30:00|  16|     Monday|  Apr|     Weekday|
# |          2021-04-03|   23:30:00|  23|     Friday|  Apr|     Weekday|
# |          2021-04-12|   09:04:00|   9|     Sunday|  Apr|     Weekend|
# |          2022-01-13|   17:20:00|  17|  Wednesday|  Jan|     Weekday|
# |          2021-04-20|   11:36:00|  11|     Monday|  Apr|     Weekday|
# |          2021-01-08|   05:00:00|   5|   Thursday|  Jan|     Weekday|
# |          2022-05-23|   11:40:00|  11|     Sunday|  May|     Weekend|
# +--------------------+-----------+----+-----------+-----+------------+
# only showing top 10 rows

# %%
df_time = df_time.withColumn(
    "Time_Period",
    when((col("Hour") >= 0) & (col("Hour") < 5), "Late Night")
    .when((col("Hour") >= 5) & (col("Hour") < 12), "Morning")
    .when((col("Hour") >= 12) & (col("Hour") < 17), "Afternoon")
    .when((col("Hour") >= 17) & (col("Hour") < 21), "Evening")
    .otherwise("Night")
)
df_time.groupBy("Time_Period").count().orderBy(col("count").desc()).show()
# Out:
# +-----------+-----+
# |Time_Period|count|
# +-----------+-----+
# |  Afternoon|66856|
# |    Morning|56379|
# |    Evening|48896|
# |      Night|15799|
# | Late Night| 9714|
# +-----------+-----+

# %%
df_time.groupBy("Hour").count().orderBy(col("count").desc()).show(24)
# Out:
# +----+-----+
# |Hour|count|
# +----+-----+
# |  17|17134|
# |  16|15682|
# |  15|15403|
# |   8|14452|
# |  18|13824|
# |  13|12138|
# |  14|12089|
# |  12|11544|
# |  19|10439|
# |  11|10135|
# |   9| 9998|
# |  10| 8746|
# |   7| 7995|
# |  20| 7499|
# |  21| 6215|
# |  22| 5372|
# |  23| 4212|
# |   6| 3394|
# |   0| 3058|
# |   1| 2305|
# |   2| 1679|
# |   5| 1659|
# |   3| 1522|
# |   4| 1150|
# +----+-----+

# %%
df_time.groupBy("Day_of_Week").count().orderBy(col("count").desc()).show()
# Out:
# +-----------+-----+
# |Day_of_Week|count|
# +-----------+-----+
# |     Friday|32376|
# |    Tuesday|29853|
# |  Wednesday|29850|
# |   Thursday|29389|
# |     Monday|28154|
# |   Saturday|26544|
# |     Sunday|21478|
# +-----------+-----+

# %%
df_time.groupBy("Month").count().orderBy(col("count").desc()).show(12)
# Out:
# +-----+-----+
# |Month|count|
# +-----+-----+
# |  Nov|18650|
# |  Oct|18310|
# |  Jul|17356|
# |  Sep|17129|
# |  Jun|17122|
# |  May|16838|
# |  Mar|16567|
# |  Aug|16238|
# |  Apr|15496|
# |  Jan|14962|
# |  Dec|14881|
# |  Feb|14095|
# +-----+-----+

# %%
df_time.groupBy("Weekend_Flag").count().show()
# Out:
# +------------+------+
# |Weekend_Flag| count|
# +------------+------+
# |     Weekday|149622|
# |     Weekend| 48022|
# +------------+------+

# %%
risk_periods = df_time.groupBy("Time_Period", "Weekend_Flag").count().orderBy(col("count").desc())
risk_periods.show(5)
# Out:
# +-----------+------------+-----+
# |Time_Period|Weekend_Flag|count|
# +-----------+------------+-----+
# |  Afternoon|     Weekday|49971|
# |    Morning|     Weekday|45953|
# |    Evening|     Weekday|38147|
# |  Afternoon|     Weekend|16885|
# |      Night|     Weekday|11226|
# +-----------+------------+-----+
# only showing top 5 rows

# %%
from pyspark.sql.functions import sum as spark_sum, count as spark_count

df_severity = df_time.withColumn(
    "Severity_Weight",
    when(col("Accident_Severity") == "Slight", 1)
    .when(col("Accident_Severity") == "Serious", 3)
    .when(col("Accident_Severity") == "Fatal", 5)
    .otherwise(0)
)

df_severity.groupBy("Accident_Severity", "Severity_Weight").count().show()
# Out:
# +-----------------+---------------+------+
# |Accident_Severity|Severity_Weight| count|
# +-----------------+---------------+------+
# |          Serious|              3| 25685|
# |            Fatal|              5|  2486|
# |           Slight|              1|169473|
# +-----------------+---------------+------+

# %%
severity_by_location = df_severity.groupBy("Local_Authority_(District)") \
    .agg(
        spark_count("Accident_Index").alias("Accident_Count"),
        spark_sum("Severity_Weight").alias("Severity_Score")
    ) \
    .orderBy(col("Severity_Score").desc())

severity_by_location.show(15, truncate=False)
# Out:
# +--------------------------+--------------+--------------+
# |Local_Authority_(District)|Accident_Count|Severity_Score|
# +--------------------------+--------------+--------------+
# |Birmingham                |6165          |7805          |
# |Westminster               |2811          |4341          |
# |Manchester                |3132          |3854          |
# |Sheffield                 |2750          |3464          |
# |Liverpool                 |2611          |3445          |
# |Cornwall                  |2606          |3288          |
# |County Durham             |2228          |2904          |
# |Lambeth                   |2250          |2884          |
# |Barnet                    |2302          |2830          |
# |Southwark                 |1977          |2579          |
# |Camden                    |1671          |2529          |
# |Doncaster                 |1945          |2509          |
# |Nottingham                |1931          |2499          |
# |Wiltshire                 |1590          |2390          |
# |East Riding of Yorkshire  |1558          |2302          |
# +--------------------------+--------------+--------------+
# only showing top 15 rows

# %%
severity_by_roadtype = df_severity.groupBy("Road_Type") \
    .agg(
        spark_count("Accident_Index").alias("Accident_Count"),
        spark_sum("Severity_Weight").alias("Severity_Score")
    ) \
    .orderBy(col("Severity_Score").desc())

severity_by_roadtype.show(truncate=False)
# Out:
# +------------------+--------------+--------------+
# |Road_Type         |Accident_Count|Severity_Score|
# +------------------+--------------+--------------+
# |Single carriageway|148543        |196689        |
# |Dual carriageway  |29004         |38022         |
# |Roundabout        |13196         |15648         |
# |One way street    |3937          |5069          |
# |Slip road         |1951          |2297          |
# |Unknown           |1013          |1233          |
# +------------------+--------------+--------------+

# %%
severity_by_roadtype = df_severity.groupBy("Road_Type") \
    .agg(
        spark_count("Accident_Index").alias("Accident_Count"),
        spark_sum("Severity_Weight").alias("Severity_Score")
    ) \
    .orderBy(col("Severity_Score").desc())

severity_by_roadtype.show(truncate=False)
# Out:
# +------------------+--------------+--------------+
# |Road_Type         |Accident_Count|Severity_Score|
# +------------------+--------------+--------------+
# |Single carriageway|148543        |196689        |
# |Dual carriageway  |29004         |38022         |
# |Roundabout        |13196         |15648         |
# |One way street    |3937          |5069          |
# |Slip road         |1951          |2297          |
# |Unknown           |1013          |1233          |
# +------------------+--------------+--------------+

# %%
severity_by_timeperiod = df_severity.groupBy("Time_Period") \
    .agg(
        spark_count("Accident_Index").alias("Accident_Count"),
        spark_sum("Severity_Weight").alias("Severity_Score")
    ) \
    .orderBy(col("Severity_Score").desc())

severity_by_timeperiod.show(truncate=False)
# Out:
# +-----------+--------------+--------------+
# |Time_Period|Accident_Count|Severity_Score|
# +-----------+--------------+--------------+
# |Afternoon  |66856         |86082         |
# |Morning    |56379         |72461         |
# |Evening    |48896         |63872         |
# |Night      |15799         |21797         |
# |Late Night |9714          |14746         |
# +-----------+--------------+--------------+

# %%
# Compare rank by raw count vs rank by severity score for locations
severity_by_location.withColumn(
    "Avg_Severity_Per_Accident", col("Severity_Score") / col("Accident_Count")
).orderBy(col("Avg_Severity_Per_Accident").desc()).show(15, truncate=False)
# Out:
# +--------------------------+--------------+--------------+-------------------------+
# |Local_Authority_(District)|Accident_Count|Severity_Score|Avg_Severity_Per_Accident|
# +--------------------------+--------------+--------------+-------------------------+
# |Dundee City               |2             |4             |2.0                      |
# |South Staffordshire       |6             |10            |1.6666666666666667       |
# |South Northamptonshire    |413           |681           |1.6489104116222761       |
# |Oswestry                  |30            |48            |1.6                      |
# |Maldon                    |245           |389           |1.5877551020408163       |
# |Daventry                  |395           |621           |1.5721518987341772       |
# |Purbeck                   |265           |413           |1.558490566037736        |
# |South Larkshire           |338           |524           |1.5502958579881656       |
# |East Northamptonshire     |275           |425           |1.5454545454545454       |
# |Westminster               |2811          |4341          |1.544290288153682        |
# |City of London            |635           |977           |1.5385826771653544       |
# |Powys                     |857           |1315          |1.5344224037339556       |
# |Argyll and Bute           |280           |428           |1.5285714285714285       |
# |Derbyshire Dales          |483           |735           |1.5217391304347827       |
# |Camden                    |1671          |2529          |1.5134649910233393       |
# +--------------------------+--------------+--------------+-------------------------+
# only showing top 15 rows

# %%
combo_severity = df_severity.groupBy(
    "Road_Type", "Speed_limit", "Weather_Conditions", "Time_Period", "Vehicle_Type"
).agg(
    spark_count("Accident_Index").alias("Accident_Count"),
    spark_sum("Severity_Weight").alias("Severity_Score")
).orderBy(col("Severity_Score").desc())

combo_severity.show(10, truncate=False)
# Out:
# +------------------+-----------+---------------------+-----------+------------+--------------+--------------+
# |Road_Type         |Speed_limit|Weather_Conditions   |Time_Period|Vehicle_Type|Accident_Count|Severity_Score|
# +------------------+-----------+---------------------+-----------+------------+--------------+--------------+
# |Single carriageway|30         |Fine no high winds   |Afternoon  |Car         |25659         |32487         |
# |Single carriageway|30         |Fine no high winds   |Morning    |Car         |19412         |24610         |
# |Single carriageway|30         |Fine no high winds   |Evening    |Car         |17807         |22993         |
# |Single carriageway|30         |Fine no high winds   |Night      |Car         |5345          |7295          |
# |Single carriageway|60         |Fine no high winds   |Afternoon  |Car         |4346          |6808          |
# |Single carriageway|60         |Fine no high winds   |Morning    |Car         |4164          |5980          |
# |Single carriageway|30         |Fine no high winds   |Late Night |Car         |3228          |4842          |
# |Single carriageway|60         |Fine no high winds   |Evening    |Car         |2900          |4520          |
# |Single carriageway|30         |Raining no high winds|Evening    |Car         |2839          |3581          |
# |Single carriageway|30         |Raining no high winds|Afternoon  |Car         |2867          |3549          |
# +------------------+-----------+---------------------+-----------+------------+--------------+--------------+
# only showing top 10 rows

# %%
combo_severity_filtered = combo_severity.filter(col("Accident_Count") >= 30) \
    .withColumn("Avg_Severity", col("Severity_Score") / col("Accident_Count")) \
    .orderBy(col("Avg_Severity").desc())

combo_severity_filtered.show(10, truncate=False)
# Out:
# +------------------+-----------+---------------------+-----------+-----------------------------------+--------------+--------------+------------------+
# |Road_Type         |Speed_limit|Weather_Conditions   |Time_Period|Vehicle_Type                       |Accident_Count|Severity_Score|Avg_Severity      |
# +------------------+-----------+---------------------+-----------+-----------------------------------+--------------+--------------+------------------+
# |Dual carriageway  |70         |Fine no high winds   |Late Night |Van / Goods 3.5 tonnes mgw or under|33            |67            |2.0303030303030303|
# |Single carriageway|60         |Fine no high winds   |Late Night |Van / Goods 3.5 tonnes mgw or under|48            |92            |1.9166666666666667|
# |Single carriageway|40         |Fine no high winds   |Late Night |Car                                |230           |416           |1.808695652173913 |
# |Single carriageway|60         |Fine no high winds   |Evening    |Motorcycle 125cc and under         |78            |140           |1.794871794871795 |
# |Dual carriageway  |40         |Raining no high winds|Late Night |Car                                |33            |59            |1.7878787878787878|
# |Single carriageway|60         |Fine no high winds   |Afternoon  |Motorcycle 50cc and under          |66            |118           |1.7878787878787878|
# |Single carriageway|60         |Fine no high winds   |Night      |Van / Goods 3.5 tonnes mgw or under|73            |127           |1.7397260273972603|
# |Dual carriageway  |70         |Fine no high winds   |Late Night |Car                                |433           |753           |1.7390300230946882|
# |Single carriageway|30         |Fine no high winds   |Late Night |Motorcycle 125cc and under         |95            |163           |1.7157894736842105|
# |Single carriageway|60         |Fine no high winds   |Evening    |Goods 7.5 tonnes mgw and over      |79            |135           |1.7088607594936709|
# +------------------+-----------+---------------------+-----------+-----------------------------------+--------------+--------------+------------------+
# only showing top 10 rows

# %% [markdown]
# ## Task 6

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import dense_rank, rank, row_number

location_risk = df_severity.groupBy("Urban_or_Rural_Area", "Local_Authority_(District)") \
    .agg(
        spark_count("Accident_Index").alias("Accident_Count"),
        spark_sum("Severity_Weight").alias("Severity_Score")
    )

location_risk.show(10, truncate=False)
# Out:
# +-------------------+--------------------------+--------------+--------------+
# |Urban_or_Rural_Area|Local_Authority_(District)|Accident_Count|Severity_Score|
# +-------------------+--------------------------+--------------+--------------+
# |Rural              |North Kesteven            |582           |876           |
# |Urban              |East Dorset               |166           |230           |
# |Rural              |South Ribble              |391           |525           |
# |Rural              |Trafford                  |93            |125           |
# |Urban              |Derbyshire Dales          |32            |38            |
# |Urban              |Chesterfield              |474           |590           |
# |Urban              |East Northamptonshire     |59            |79            |
# |Rural              |West Wiltshire            |27            |31            |
# |Rural              |Denbighshire              |174           |238           |
# |Urban              |Kensington and Chelsea    |1376          |1792          |
# +-------------------+--------------------------+--------------+--------------+
# only showing top 10 rows

# %%
window_spec = Window.partitionBy("Urban_or_Rural_Area").orderBy(col("Severity_Score").desc())

location_ranked = location_risk.withColumn(
    "Risk_Rank", dense_rank().over(window_spec)
)

top3_per_category = location_ranked.filter(col("Risk_Rank") <= 3) \
    .orderBy("Urban_or_Rural_Area", "Risk_Rank")

top3_per_category.show(20, truncate=False)
# Out:
# +-------------------+--------------------------+--------------+--------------+---------+
# |Urban_or_Rural_Area|Local_Authority_(District)|Accident_Count|Severity_Score|Risk_Rank|
# +-------------------+--------------------------+--------------+--------------+---------+
# |Rural              |Cornwall                  |1992          |2584          |1        |
# |Rural              |County Durham             |1421          |1903          |2        |
# |Rural              |Wiltshire                 |1158          |1816          |3        |
# |Urban              |Birmingham                |6099          |7717          |1        |
# |Urban              |Westminster               |2811          |4341          |2        |
# |Urban              |Manchester                |3072          |3772          |3        |
# +-------------------+--------------------------+--------------+--------------+---------+

# %%
location_risk_pf = df_severity.groupBy("Police_Force", "Local_Authority_(District)") \
    .agg(
        spark_count("Accident_Index").alias("Accident_Count"),
        spark_sum("Severity_Weight").alias("Severity_Score")
    )

window_spec_pf = Window.partitionBy("Police_Force").orderBy(col("Severity_Score").desc())

location_ranked_pf = location_risk_pf.withColumn(
    "Risk_Rank", dense_rank().over(window_spec_pf)
)

top3_per_pf = location_ranked_pf.filter(col("Risk_Rank") <= 3) \
    .orderBy("Police_Force", "Risk_Rank")

top3_per_pf.show(30, truncate=False)
# Out:
# +------------------+--------------------------+--------------+--------------+---------+
# |Police_Force      |Local_Authority_(District)|Accident_Count|Severity_Score|Risk_Rank|
# +------------------+--------------------------+--------------+--------------+---------+
# |Bedfordshire      |Central Bedfordshire      |1225          |1691          |1        |
# |Bedfordshire      |Luton                     |998           |1224          |2        |
# |Bedfordshire      |Bedford                   |792           |1016          |3        |
# |City of London    |City of London            |635           |977           |1        |
# |Cleveland         |Stockton-on-Tees          |628           |858           |1        |
# |Cleveland         |Middlesbrough             |597           |737           |2        |
# |Cleveland         |Redcar and Cleveland      |444           |610           |3        |
# |Cumbria           |Eden                      |1             |1             |1        |
# |Derbyshire        |Derby                     |1619          |2015          |1        |
# |Derbyshire        |Amber Valley              |629           |811           |2        |
# |Derbyshire        |Erewash                   |570           |770           |3        |
# |Devon and Cornwall|Cornwall                  |2606          |3288          |1        |
# |Devon and Cornwall|Plymouth                  |1396          |1614          |2        |
# |Devon and Cornwall|Teignbridge               |723           |899           |3        |
# |Dorset            |Bournemouth               |1074          |1366          |1        |
# |Dorset            |Poole                     |758           |964           |2        |
# |Dorset            |West Dorset               |584           |856           |3        |
# |Durham            |County Durham             |2228          |2904          |1        |
# |Durham            |Darlington                |541           |689           |2        |
# |Durham            |Durham                    |78            |100           |3        |
# |Dyfed-Powys       |Carmarthenshire           |990           |1356          |1        |
# |Dyfed-Powys       |Powys                     |857           |1315          |2        |
# |Dyfed-Powys       |Pembrokeshire             |715           |973           |3        |
# |Essex             |Epping Forest             |924           |1312          |1        |
# |Essex             |Chelmsford                |872           |1190          |2        |
# |Essex             |Southend-on-Sea           |883           |1177          |3        |
# |Greater Manchester|Manchester                |3132          |3854          |1        |
# |Greater Manchester|Bolton                    |1231          |1567          |2        |
# |Greater Manchester|Wigan                     |1133          |1457          |3        |
# |Hertfordshire     |St. Albans                |850           |1078          |1        |
# +------------------+--------------------------+--------------+--------------+---------+
# only showing top 30 rows

# %% [markdown]
# ## Task 7

# %%
from pyspark.sql.functions import avg as spark_avg

# Component 1 & 2: frequency and severity (reuse from Task 6, but at national level this time)
location_components = df_severity.groupBy("Local_Authority_(District)").agg(
    spark_count("Accident_Index").alias("Accident_Count"),
    spark_sum("Severity_Weight").alias("Severity_Score")
)

# Component 3: dangerous conditions rate — % of accidents in non-"Fine"/non-"Dry" conditions
df_severity = df_severity.withColumn(
    "Is_Dangerous_Condition",
    when(
        (col("Weather_Conditions") != "Fine no high winds") |
        (col("Road_Surface_Conditions") != "Dry"),
        1
    ).otherwise(0)
)

danger_rate = df_severity.groupBy("Local_Authority_(District)").agg(
    spark_avg("Is_Dangerous_Condition").alias("Dangerous_Condition_Rate")
)

location_components = location_components.join(danger_rate, on="Local_Authority_(District)", how="left")
location_components.show(10, truncate=False)
# Out:
# +--------------------------+--------------+--------------+------------------------+
# |Local_Authority_(District)|Accident_Count|Severity_Score|Dangerous_Condition_Rate|
# +--------------------------+--------------+--------------+------------------------+
# |Worcester                 |433           |489           |0.3117782909930716      |
# |North Wiltshire           |70            |96            |0.6142857142857143      |
# |North Kesteven            |705           |1035          |0.49361702127659574     |
# |Waveney                   |593           |811           |0.3524451939291737      |
# |Epping Forest             |924           |1312          |0.36363636363636365     |
# |North Cornwall            |58            |74            |0.5689655172413793      |
# |Maldon                    |245           |389           |0.40816326530612246     |
# |St. Edmundsbury           |562           |778           |0.43416370106761565     |
# |Guildford                 |1182          |1486          |0.4103214890016921      |
# |Bolton                    |1231          |1567          |0.39886271324126726     |
# +--------------------------+--------------+--------------+------------------------+
# only showing top 10 rows

# %%
from pyspark.sql.functions import min as spark_min, max as spark_max, lit

def minmax_normalize(df, colname, new_colname):
    stats = df.agg(spark_min(colname).alias("min_val"), spark_max(colname).alias("max_val")).collect()[0]
    min_val, max_val = stats["min_val"], stats["max_val"]
    return df.withColumn(
        new_colname,
        (col(colname) - lit(min_val)) / (lit(max_val) - lit(min_val))
    )

location_components = minmax_normalize(location_components, "Accident_Count", "Norm_Frequency")
location_components = minmax_normalize(location_components, "Severity_Score", "Norm_Severity")
location_components = minmax_normalize(location_components, "Dangerous_Condition_Rate", "Norm_Danger")

location_components.select(
    "Local_Authority_(District)", "Norm_Frequency", "Norm_Severity", "Norm_Danger"
).show(10, truncate=False)
# Out:
# +--------------------------+--------------------+--------------------+-------------------+
# |Local_Authority_(District)|Norm_Frequency      |Norm_Severity       |Norm_Danger        |
# +--------------------------+--------------------+--------------------+-------------------+
# |Worcester                 |0.07008436080467229 |0.06253203485392107 |0.3117782909930716 |
# |North Wiltshire           |0.011194029850746268|0.012173244490005125|0.6142857142857143 |
# |North Kesteven            |0.11421155094094744 |0.13249615581752947 |0.49361702127659574|
# |Waveney                   |0.09604153147306943 |0.10379292670425423 |0.3524451939291737 |
# |Epping Forest             |0.14974042829331602 |0.16799077396207074 |0.36363636363636365|
# |North Cornwall            |0.009247242050616482|0.009354177344951307|0.5689655172413793 |
# |Maldon                    |0.03958468526930565 |0.04971809328549462 |0.40816326530612246|
# |St. Edmundsbury           |0.0910123296560675  |0.0995643259866735  |0.43416370106761565|
# |Guildford                 |0.19159636599610644 |0.19028703229113275 |0.4103214890016921 |
# |Bolton                    |0.19954574951330306 |0.20066632496155817 |0.39886271324126726|
# +--------------------------+--------------------+--------------------+-------------------+
# only showing top 10 rows

# %%
location_components = location_components.withColumn(
    "Road_Safety_Risk_Score",
    (col("Norm_Severity") * 0.5) +
    (col("Norm_Frequency") * 0.35) +
    (col("Norm_Danger") * 0.15)
)

ranked_risk = location_components.orderBy(col("Road_Safety_Risk_Score").desc())
ranked_risk.select(
    "Local_Authority_(District)", "Accident_Count", "Severity_Score",
    "Dangerous_Condition_Rate", "Road_Safety_Risk_Score"
).show(15, truncate=False)
# Out:
# +--------------------------+--------------+--------------+------------------------+----------------------+
# |Local_Authority_(District)|Accident_Count|Severity_Score|Dangerous_Condition_Rate|Road_Safety_Risk_Score|
# +--------------------------+--------------+--------------+------------------------+----------------------+
# |Birmingham                |6165          |7805          |0.36253041362530414     |0.9043795620437955    |
# |Manchester                |3132          |3854          |0.39655172413793105     |0.484125627167444     |
# |Westminster               |2811          |4341          |0.2113127001067236      |0.46931492050316614   |
# |Sheffield                 |2750          |3464          |0.3618181818181818      |0.43223794902127066   |
# |Liverpool                 |2611          |3445          |0.32707774798927614     |0.4179169572915748    |
# |Cornwall                  |2606          |3288          |0.3883346124328473      |0.41676263627271015   |
# |County Durham             |2228          |2904          |0.400359066427289       |0.3725002010640667    |
# |Barnet                    |2302          |2830          |0.2736750651607298      |0.3529582594957118    |
# |Lambeth                   |2250          |2884          |0.2137777777777778      |0.344480802448214     |
# |Doncaster                 |1945          |2509          |0.3557840616966581      |0.3244373047899252    |
# |Nottingham                |1931          |2499          |0.338684619368203       |0.32043675301051594   |
# |Southwark                 |1977          |2579          |0.2357106727364694      |0.312728177941634     |
# |Wiltshire                 |1590          |2390          |0.3352201257861635      |0.2935710538229601    |
# |Camden                    |1671          |2529          |0.2256134051466188      |0.29063502129489144   |
# |East Riding of Yorkshire  |1558          |2302          |0.35365853658536583     |0.28888167920594504   |
# +--------------------------+--------------+--------------+------------------------+----------------------+
# only showing top 15 rows

# %% [markdown]
# ## Task 8

# %%
df_severity.groupBy("Local_Authority_(District)") \
    .agg(
        spark_count("Accident_Index").alias("Accident_Count"),
        spark_sum("Severity_Weight").alias("Severity_Score")
    ).explain(True)
# Out:
# == Parsed Logical Plan ==
# 'Aggregate ['Local_Authority_(District)], ['Local_Authority_(District), 'count('Accident_Index) AS Accident_Count#3798, 'sum('Severity_Weight) AS Severity_Score#3799]
# +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#224, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221, ... 6 more fields]
#    +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#224, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221, ... 5 more fields]
#       +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#224, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221, ... 4 more fields]
#          +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#224, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221, ... 3 more fields]
#             +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#224, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221, ... 2 more fields]
#                +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#224, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221, ... 1 more fields]
#                   +- Deduplicate [Accident_Index#195]
#                      +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, CASE WHEN (isnull(Weather_Conditions#216) OR (Weather_Conditions#216 = )) THEN Unknown ELSE Weather_Conditions#216 END AS Weather_Conditions#224, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221]
#                         +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, CASE WHEN (isnull(Road_Type#212) OR (Road_Type#212 = )) THEN Unknown ELSE Road_Type#212 END AS Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221]
#                            +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, CASE WHEN (isnull(Road_Surface_Conditions#211) OR (Road_Surface_Conditions#211 = )) THEN Unknown ELSE Road_Surface_Conditions#211 END AS Road_Surface_Conditions#222, Road_Type#212, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221]
#                               +- Filter isnotnull(Time#219)
#                                  +- Deduplicate [Day_of_Week#198, Police_Force#210, Vehicle_Type#217, Road_Type#212, Junction_Control#200, Number_of_Vehicles#209, Number_of_Casualties#208, Year#199, Accident Date#196, Road_Surface_Conditions#211, Junction_Detail#201, Accident_Index#195, Latitude#203, Accident_Date_Parsed#220, Longitude#207, Month#197, Local_Authority_(District)#205, Accident_Severity#202, Light_Conditions#204, Time#219, Carriageway_Hazards#206, Urban_or_Rural_Area#215, Weather_Conditions#216, Time_of_Day#221, Speed_limit#213]
#                                     +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#211, Road_Type#212, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217, Accident_Date_Parsed#220, date_format(cast(Time#219 as timestamp), HH:mm:ss, Some(Africa/Johannesburg)) AS Time_of_Day#221]
#                                        +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#211, Road_Type#212, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217, to_date(Accident Date#196, Some(M/d/yyyy), Some(Africa/Johannesburg), true) AS Accident_Date_Parsed#220]
#                                           +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#211, Road_Type#212, Speed_limit#213, cast(Time#214 as string) AS Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217]
#                                              +- Relation [Accident_Index#195,Accident Date#196,Month#197,Day_of_Week#198,Year#199,Junction_Control#200,Junction_Detail#201,Accident_Severity#202,Latitude#203,Light_Conditions#204,Local_Authority_(District)#205,Carriageway_Hazards#206,Longitude#207,Number_of_Casualties#208,Number_of_Vehicles#209,Police_Force#210,Road_Surface_Conditions#211,Road_Type#212,Speed_limit#213,Time#214,Urban_or_Rural_Area#215,Weather_Conditions#216,Vehicle_Type#217] csv
#
# == Analyzed Logical Plan ==
# Local_Authority_(District): string, Accident_Count: bigint, Severity_Score: bigint
# Aggregate [Local_Authority_(District)#205], [Local_Authority_(District)#205, count(Accident_Index#195) AS Accident_Count#3798L, sum(Severity_Weight#1043) AS Severity_Score#3799L]
# +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#224, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221, ... 6 more fields]
#    +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#224, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221, ... 5 more fields]
#       +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#224, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221, ... 4 more fields]
#          +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#224, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221, ... 3 more fields]
#             +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#224, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221, ... 2 more fields]
#                +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#224, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221, ... 1 more fields]
#                   +- Deduplicate [Accident_Index#195]
#                      +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, CASE WHEN (isnull(Weather_Conditions#216) OR (Weather_Conditions#216 = )) THEN Unknown ELSE Weather_Conditions#216 END AS Weather_Conditions#224, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221]
#                         +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, CASE WHEN (isnull(Road_Type#212) OR (Road_Type#212 = )) THEN Unknown ELSE Road_Type#212 END AS Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221]
#                            +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, CASE WHEN (isnull(Road_Surface_Conditions#211) OR (Road_Surface_Conditions#211 = )) THEN Unknown ELSE Road_Surface_Conditions#211 END AS Road_Surface_Conditions#222, Road_Type#212, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221]
#                               +- Filter isnotnull(Time#219)
#                                  +- Deduplicate [Day_of_Week#198, Police_Force#210, Vehicle_Type#217, Road_Type#212, Junction_Control#200, Number_of_Vehicles#209, Number_of_Casualties#208, Year#199, Accident Date#196, Road_Surface_Conditions#211, Junction_Detail#201, Accident_Index#195, Latitude#203, Accident_Date_Parsed#220, Longitude#207, Month#197, Local_Authority_(District)#205, Accident_Severity#202, Light_Conditions#204, Time#219, Carriageway_Hazards#206, Urban_or_Rural_Area#215, Weather_Conditions#216, Time_of_Day#221, Speed_limit#213]
#                                     +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#211, Road_Type#212, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217, Accident_Date_Parsed#220, date_format(cast(Time#219 as timestamp), HH:mm:ss, Some(Africa/Johannesburg)) AS Time_of_Day#221]
#                                        +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#211, Road_Type#212, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217, to_date(Accident Date#196, Some(M/d/yyyy), Some(Africa/Johannesburg), true) AS Accident_Date_Parsed#220]
#                                           +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#211, Road_Type#212, Speed_limit#213, cast(Time#214 as string) AS Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217]
#                                              +- Relation [Accident_Index#195,Accident Date#196,Month#197,Day_of_Week#198,Year#199,Junction_Control#200,Junction_Detail#201,Accident_Severity#202,Latitude#203,Light_Conditions#204,Local_Authority_(District)#205,Carriageway_Hazards#206,Longitude#207,Number_of_Casualties#208,Number_of_Vehicles#209,Police_Force#210,Road_Surface_Conditions#211,Road_Type#212,Speed_limit#213,Time#214,Urban_or_Rural_Area#215,Weather_Conditions#216,Vehicle_Type#217] csv
#
# == Optimized Logical Plan ==
# Aggregate [Local_Authority_(District)#3852], [Local_Authority_(District)#3852, count(Accident_Index#195) AS Accident_Count#3798L, sum(Severity_Weight#1043) AS Severity_Score#3799L]
# +- Project [Accident_Index#195, Local_Authority_(District)#3852, CASE WHEN (Accident_Severity#3846 = Slight) THEN 1 WHEN (Accident_Severity#3846 = Serious) THEN 3 WHEN (Accident_Severity#3846 = Fatal) THEN 5 ELSE 0 END AS Severity_Weight#1043]
#    +- Aggregate [Accident_Index#195], [Accident_Index#195, first(Accident_Severity#202, false) AS Accident_Severity#3846, first(Local_Authority_(District)#205, false) AS Local_Authority_(District)#3852]
#       +- Project [Accident_Index#195, Accident_Severity#202, Local_Authority_(District)#205]
#          +- Filter (isnotnull(Time#214) AND isnotnull(cast(Time#214 as string)))
#             +- Relation [Accident_Index#195,Accident Date#196,Month#197,Day_of_Week#198,Year#199,Junction_Control#200,Junction_Detail#201,Accident_Severity#202,Latitude#203,Light_Conditions#204,Local_Authority_(District)#205,Carriageway_Hazards#206,Longitude#207,Number_of_Casualties#208,Number_of_Vehicles#209,Police_Force#210,Road_Surface_Conditions#211,Road_Type#212,Speed_limit#213,Time#214,Urban_or_Rural_Area#215,Weather_Conditions#216,Vehicle_Type#217] csv
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- HashAggregate(keys=[Local_Authority_(District)#3852], functions=[count(Accident_Index#195), sum(Severity_Weight#1043)], output=[Local_Authority_(District)#3852, Accident_Count#3798L, Severity_Score#3799L])
#    +- Exchange hashpartitioning(Local_Authority_(District)#3852, 200), ENSURE_REQUIREMENTS, [plan_id=5725]
#       +- HashAggregate(keys=[Local_Authority_(District)#3852], functions=[partial_count(Accident_Index#195), partial_sum(Severity_Weight#1043)], output=[Local_Authority_(District)#3852, count#3883L, sum#3884L])
#          +- Project [Accident_Index#195, Local_Authority_(District)#3852, CASE WHEN (Accident_Severity#3846 = Slight) THEN 1 WHEN (Accident_Severity#3846 = Serious) THEN 3 WHEN (Accident_Severity#3846 = Fatal) THEN 5 ELSE 0 END AS Severity_Weight#1043]
#             +- SortAggregate(key=[Accident_Index#195], functions=[first(Accident_Severity#202, false), first(Local_Authority_(District)#205, false)], output=[Accident_Index#195, Accident_Severity#3846, Local_Authority_(District)#3852])
#                +- Sort [Accident_Index#195 ASC NULLS FIRST], false, 0
#                   +- Exchange hashpartitioning(Accident_Index#195, 200), ENSURE_REQUIREMENTS, [plan_id=5719]
#                      +- SortAggregate(key=[Accident_Index#195], functions=[partial_first(Accident_Severity#202, false), partial_first(Local_Authority_(District)#205, false)], output=[Accident_Index#195, first#3889, valueSet#3890, first#3891, valueSet#3892])
#                         +- Sort [Accident_Index#195 ASC NULLS FIRST], false, 0
#                            +- Project [Accident_Index#195, Accident_Severity#202, Local_Authority_(District)#205]
#                               +- Filter (isnotnull(Time#214) AND isnotnull(cast(Time#214 as string)))
#                                  +- FileScan csv [Accident_Index#195,Accident_Severity#202,Local_Authority_(District)#205,Time#214] Batched: false, DataFilters: [isnotnull(Time#214), isnotnull(cast(Time#214 as string))], Format: CSV, Location: InMemoryFileIndex(1 paths)[hdfs://localhost:9000/rrsis/data/Road Accident Data.csv], PartitionFilters: [], PushedFilters: [IsNotNull(Time)], ReadSchema: struct<Accident_Index:string,Accident_Severity:string,Local_Authority_(District):string,Time:time...

# %%
location_ranked.explain(True)
# Out:
# == Parsed Logical Plan ==
# 'Project [unresolvedstarwithcolumns(Risk_Rank, 'dense_rank() windowspecdefinition('Urban_or_Rural_Area, 'Severity_Score DESC NULLS LAST, unspecifiedframe$()), None)]
# +- Aggregate [Urban_or_Rural_Area#215, Local_Authority_(District)#205], [Urban_or_Rural_Area#215, Local_Authority_(District)#205, count(Accident_Index#195) AS Accident_Count#2118L, sum(Severity_Weight#1043) AS Severity_Score#2119L]
#    +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#224, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221, ... 5 more fields]
#       +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#224, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221, ... 4 more fields]
#          +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#224, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221, ... 3 more fields]
#             +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#224, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221, ... 2 more fields]
#                +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#224, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221, ... 1 more fields]
#                   +- Deduplicate [Accident_Index#195]
#                      +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, CASE WHEN (isnull(Weather_Conditions#216) OR (Weather_Conditions#216 = )) THEN Unknown ELSE Weather_Conditions#216 END AS Weather_Conditions#224, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221]
#                         +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, CASE WHEN (isnull(Road_Type#212) OR (Road_Type#212 = )) THEN Unknown ELSE Road_Type#212 END AS Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221]
#                            +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, CASE WHEN (isnull(Road_Surface_Conditions#211) OR (Road_Surface_Conditions#211 = )) THEN Unknown ELSE Road_Surface_Conditions#211 END AS Road_Surface_Conditions#222, Road_Type#212, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221]
#                               +- Filter isnotnull(Time#219)
#                                  +- Deduplicate [Day_of_Week#198, Police_Force#210, Vehicle_Type#217, Road_Type#212, Junction_Control#200, Number_of_Vehicles#209, Number_of_Casualties#208, Year#199, Accident Date#196, Road_Surface_Conditions#211, Junction_Detail#201, Accident_Index#195, Latitude#203, Accident_Date_Parsed#220, Longitude#207, Month#197, Local_Authority_(District)#205, Accident_Severity#202, Light_Conditions#204, Time#219, Carriageway_Hazards#206, Urban_or_Rural_Area#215, Weather_Conditions#216, Time_of_Day#221, Speed_limit#213]
#                                     +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#211, Road_Type#212, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217, Accident_Date_Parsed#220, date_format(cast(Time#219 as timestamp), HH:mm:ss, Some(Africa/Johannesburg)) AS Time_of_Day#221]
#                                        +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#211, Road_Type#212, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217, to_date(Accident Date#196, Some(M/d/yyyy), Some(Africa/Johannesburg), true) AS Accident_Date_Parsed#220]
#                                           +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#211, Road_Type#212, Speed_limit#213, cast(Time#214 as string) AS Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217]
#                                              +- Relation [Accident_Index#195,Accident Date#196,Month#197,Day_of_Week#198,Year#199,Junction_Control#200,Junction_Detail#201,Accident_Severity#202,Latitude#203,Light_Conditions#204,Local_Authority_(District)#205,Carriageway_Hazards#206,Longitude#207,Number_of_Casualties#208,Number_of_Vehicles#209,Police_Force#210,Road_Surface_Conditions#211,Road_Type#212,Speed_limit#213,Time#214,Urban_or_Rural_Area#215,Weather_Conditions#216,Vehicle_Type#217] csv
#
# == Analyzed Logical Plan ==
# Urban_or_Rural_Area: string, Local_Authority_(District): string, Accident_Count: bigint, Severity_Score: bigint, Risk_Rank: int
# Project [Urban_or_Rural_Area#215, Local_Authority_(District)#205, Accident_Count#2118L, Severity_Score#2119L, Risk_Rank#2264]
# +- Project [Urban_or_Rural_Area#215, Local_Authority_(District)#205, Accident_Count#2118L, Severity_Score#2119L, Risk_Rank#2264, Risk_Rank#2264]
#    +- Window [dense_rank(Severity_Score#2119L) windowspecdefinition(Urban_or_Rural_Area#215, Severity_Score#2119L DESC NULLS LAST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS Risk_Rank#2264], [Urban_or_Rural_Area#215], [Severity_Score#2119L DESC NULLS LAST]
#       +- Project [Urban_or_Rural_Area#215, Local_Authority_(District)#205, Accident_Count#2118L, Severity_Score#2119L]
#          +- Aggregate [Urban_or_Rural_Area#215, Local_Authority_(District)#205], [Urban_or_Rural_Area#215, Local_Authority_(District)#205, count(Accident_Index#195) AS Accident_Count#2118L, sum(Severity_Weight#1043) AS Severity_Score#2119L]
#             +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#224, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221, ... 5 more fields]
#                +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#224, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221, ... 4 more fields]
#                   +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#224, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221, ... 3 more fields]
#                      +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#224, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221, ... 2 more fields]
#                         +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#224, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221, ... 1 more fields]
#                            +- Deduplicate [Accident_Index#195]
#                               +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, CASE WHEN (isnull(Weather_Conditions#216) OR (Weather_Conditions#216 = )) THEN Unknown ELSE Weather_Conditions#216 END AS Weather_Conditions#224, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221]
#                                  +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, CASE WHEN (isnull(Road_Type#212) OR (Road_Type#212 = )) THEN Unknown ELSE Road_Type#212 END AS Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221]
#                                     +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, CASE WHEN (isnull(Road_Surface_Conditions#211) OR (Road_Surface_Conditions#211 = )) THEN Unknown ELSE Road_Surface_Conditions#211 END AS Road_Surface_Conditions#222, Road_Type#212, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221]
#                                        +- Filter isnotnull(Time#219)
#                                           +- Deduplicate [Day_of_Week#198, Police_Force#210, Vehicle_Type#217, Road_Type#212, Junction_Control#200, Number_of_Vehicles#209, Number_of_Casualties#208, Year#199, Accident Date#196, Road_Surface_Conditions#211, Junction_Detail#201, Accident_Index#195, Latitude#203, Accident_Date_Parsed#220, Longitude#207, Month#197, Local_Authority_(District)#205, Accident_Severity#202, Light_Conditions#204, Time#219, Carriageway_Hazards#206, Urban_or_Rural_Area#215, Weather_Conditions#216, Time_of_Day#221, Speed_limit#213]
#                                              +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#211, Road_Type#212, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217, Accident_Date_Parsed#220, date_format(cast(Time#219 as timestamp), HH:mm:ss, Some(Africa/Johannesburg)) AS Time_of_Day#221]
#                                                 +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#211, Road_Type#212, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217, to_date(Accident Date#196, Some(M/d/yyyy), Some(Africa/Johannesburg), true) AS Accident_Date_Parsed#220]
#                                                    +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#211, Road_Type#212, Speed_limit#213, cast(Time#214 as string) AS Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217]
#                                                       +- Relation [Accident_Index#195,Accident Date#196,Month#197,Day_of_Week#198,Year#199,Junction_Control#200,Junction_Detail#201,Accident_Severity#202,Latitude#203,Light_Conditions#204,Local_Authority_(District)#205,Carriageway_Hazards#206,Longitude#207,Number_of_Casualties#208,Number_of_Vehicles#209,Police_Force#210,Road_Surface_Conditions#211,Road_Type#212,Speed_limit#213,Time#214,Urban_or_Rural_Area#215,Weather_Conditions#216,Vehicle_Type#217] csv
#
# == Optimized Logical Plan ==
# Window [dense_rank(Severity_Score#2119L) windowspecdefinition(Urban_or_Rural_Area#3932, Severity_Score#2119L DESC NULLS LAST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS Risk_Rank#2264], [Urban_or_Rural_Area#3932], [Severity_Score#2119L DESC NULLS LAST]
# +- Aggregate [Urban_or_Rural_Area#3932, Local_Authority_(District)#3912], [Urban_or_Rural_Area#3932, Local_Authority_(District)#3912, count(Accident_Index#195) AS Accident_Count#2118L, sum(Severity_Weight#1043) AS Severity_Score#2119L]
#    +- Project [Accident_Index#195, Local_Authority_(District)#3912, Urban_or_Rural_Area#3932, CASE WHEN (Accident_Severity#3906 = Slight) THEN 1 WHEN (Accident_Severity#3906 = Serious) THEN 3 WHEN (Accident_Severity#3906 = Fatal) THEN 5 ELSE 0 END AS Severity_Weight#1043]
#       +- Aggregate [Accident_Index#195], [Accident_Index#195, first(Accident_Severity#202, false) AS Accident_Severity#3906, first(Local_Authority_(District)#205, false) AS Local_Authority_(District)#3912, first(Urban_or_Rural_Area#215, false) AS Urban_or_Rural_Area#3932]
#          +- Project [Accident_Index#195, Accident_Severity#202, Local_Authority_(District)#205, Urban_or_Rural_Area#215]
#             +- Filter (isnotnull(Time#214) AND isnotnull(cast(Time#214 as string)))
#                +- Relation [Accident_Index#195,Accident Date#196,Month#197,Day_of_Week#198,Year#199,Junction_Control#200,Junction_Detail#201,Accident_Severity#202,Latitude#203,Light_Conditions#204,Local_Authority_(District)#205,Carriageway_Hazards#206,Longitude#207,Number_of_Casualties#208,Number_of_Vehicles#209,Police_Force#210,Road_Surface_Conditions#211,Road_Type#212,Speed_limit#213,Time#214,Urban_or_Rural_Area#215,Weather_Conditions#216,Vehicle_Type#217] csv
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Window [dense_rank(Severity_Score#2119L) windowspecdefinition(Urban_or_Rural_Area#3932, Severity_Score#2119L DESC NULLS LAST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS Risk_Rank#2264], [Urban_or_Rural_Area#3932], [Severity_Score#2119L DESC NULLS LAST]
#    +- Sort [Urban_or_Rural_Area#3932 ASC NULLS FIRST, Severity_Score#2119L DESC NULLS LAST], false, 0
#       +- Exchange hashpartitioning(Urban_or_Rural_Area#3932, 200), ENSURE_REQUIREMENTS, [plan_id=5769]
#          +- HashAggregate(keys=[Urban_or_Rural_Area#3932, Local_Authority_(District)#3912], functions=[count(Accident_Index#195), sum(Severity_Weight#1043)], output=[Urban_or_Rural_Area#3932, Local_Authority_(District)#3912, Accident_Count#2118L, Severity_Score#2119L])
#             +- Exchange hashpartitioning(Urban_or_Rural_Area#3932, Local_Authority_(District)#3912, 200), ENSURE_REQUIREMENTS, [plan_id=5766]
#                +- HashAggregate(keys=[Urban_or_Rural_Area#3932, Local_Authority_(District)#3912], functions=[partial_count(Accident_Index#195), partial_sum(Severity_Weight#1043)], output=[Urban_or_Rural_Area#3932, Local_Authority_(District)#3912, count#2206L, sum#2207L])
#                   +- Project [Accident_Index#195, Local_Authority_(District)#3912, Urban_or_Rural_Area#3932, CASE WHEN (Accident_Severity#3906 = Slight) THEN 1 WHEN (Accident_Severity#3906 = Serious) THEN 3 WHEN (Accident_Severity#3906 = Fatal) THEN 5 ELSE 0 END AS Severity_Weight#1043]
#                      +- SortAggregate(key=[Accident_Index#195], functions=[first(Accident_Severity#202, false), first(Local_Authority_(District)#205, false), first(Urban_or_Rural_Area#215, false)], output=[Accident_Index#195, Accident_Severity#3906, Local_Authority_(District)#3912, Urban_or_Rural_Area#3932])
#                         +- Sort [Accident_Index#195 ASC NULLS FIRST], false, 0
#                            +- Exchange hashpartitioning(Accident_Index#195, 200), ENSURE_REQUIREMENTS, [plan_id=5760]
#                               +- SortAggregate(key=[Accident_Index#195], functions=[partial_first(Accident_Severity#202, false), partial_first(Local_Authority_(District)#205, false), partial_first(Urban_or_Rural_Area#215, false)], output=[Accident_Index#195, first#3947, valueSet#3948, first#3949, valueSet#3950, first#3951, valueSet#3952])
#                                  +- Sort [Accident_Index#195 ASC NULLS FIRST], false, 0
#                                     +- Project [Accident_Index#195, Accident_Severity#202, Local_Authority_(District)#205, Urban_or_Rural_Area#215]
#                                        +- Filter (isnotnull(Time#214) AND isnotnull(cast(Time#214 as string)))
#                                           +- FileScan csv [Accident_Index#195,Accident_Severity#202,Local_Authority_(District)#205,Time#214,Urban_or_Rural_Area#215] Batched: false, DataFilters: [isnotnull(Time#214), isnotnull(cast(Time#214 as string))], Format: CSV, Location: InMemoryFileIndex(1 paths)[hdfs://localhost:9000/rrsis/data/Road Accident Data.csv], PartitionFilters: [], PushedFilters: [IsNotNull(Time)], ReadSchema: struct<Accident_Index:string,Accident_Severity:string,Local_Authority_(District):string,Time:time...

# %%
df_clean.filter(col("Speed_limit") > 30).select("Accident_Index", "Speed_limit").explain(True)
# Out:
# == Parsed Logical Plan ==
# 'Project ['Accident_Index, 'Speed_limit]
# +- Filter (Speed_limit#213 > 30)
#    +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, CASE WHEN (isnull(Weather_Conditions#216) OR (Weather_Conditions#216 = )) THEN Unknown ELSE Weather_Conditions#216 END AS Weather_Conditions#224, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221]
#       +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, CASE WHEN (isnull(Road_Type#212) OR (Road_Type#212 = )) THEN Unknown ELSE Road_Type#212 END AS Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221]
#          +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, CASE WHEN (isnull(Road_Surface_Conditions#211) OR (Road_Surface_Conditions#211 = )) THEN Unknown ELSE Road_Surface_Conditions#211 END AS Road_Surface_Conditions#222, Road_Type#212, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221]
#             +- Filter isnotnull(Time#219)
#                +- Deduplicate [Day_of_Week#198, Police_Force#210, Vehicle_Type#217, Road_Type#212, Junction_Control#200, Number_of_Vehicles#209, Number_of_Casualties#208, Year#199, Accident Date#196, Road_Surface_Conditions#211, Junction_Detail#201, Accident_Index#195, Latitude#203, Accident_Date_Parsed#220, Longitude#207, Month#197, Local_Authority_(District)#205, Accident_Severity#202, Light_Conditions#204, Time#219, Carriageway_Hazards#206, Urban_or_Rural_Area#215, Weather_Conditions#216, Time_of_Day#221, Speed_limit#213]
#                   +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#211, Road_Type#212, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217, Accident_Date_Parsed#220, date_format(cast(Time#219 as timestamp), HH:mm:ss, Some(Africa/Johannesburg)) AS Time_of_Day#221]
#                      +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#211, Road_Type#212, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217, to_date(Accident Date#196, Some(M/d/yyyy), Some(Africa/Johannesburg), true) AS Accident_Date_Parsed#220]
#                         +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#211, Road_Type#212, Speed_limit#213, cast(Time#214 as string) AS Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217]
#                            +- Relation [Accident_Index#195,Accident Date#196,Month#197,Day_of_Week#198,Year#199,Junction_Control#200,Junction_Detail#201,Accident_Severity#202,Latitude#203,Light_Conditions#204,Local_Authority_(District)#205,Carriageway_Hazards#206,Longitude#207,Number_of_Casualties#208,Number_of_Vehicles#209,Police_Force#210,Road_Surface_Conditions#211,Road_Type#212,Speed_limit#213,Time#214,Urban_or_Rural_Area#215,Weather_Conditions#216,Vehicle_Type#217] csv
#
# == Analyzed Logical Plan ==
# Accident_Index: string, Speed_limit: int
# Project [Accident_Index#195, Speed_limit#213]
# +- Filter (Speed_limit#213 > 30)
#    +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, CASE WHEN (isnull(Weather_Conditions#216) OR (Weather_Conditions#216 = )) THEN Unknown ELSE Weather_Conditions#216 END AS Weather_Conditions#224, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221]
#       +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#222, CASE WHEN (isnull(Road_Type#212) OR (Road_Type#212 = )) THEN Unknown ELSE Road_Type#212 END AS Road_Type#223, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221]
#          +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, CASE WHEN (isnull(Road_Surface_Conditions#211) OR (Road_Surface_Conditions#211 = )) THEN Unknown ELSE Road_Surface_Conditions#211 END AS Road_Surface_Conditions#222, Road_Type#212, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217, Accident_Date_Parsed#220, Time_of_Day#221]
#             +- Filter isnotnull(Time#219)
#                +- Deduplicate [Day_of_Week#198, Police_Force#210, Vehicle_Type#217, Road_Type#212, Junction_Control#200, Number_of_Vehicles#209, Number_of_Casualties#208, Year#199, Accident Date#196, Road_Surface_Conditions#211, Junction_Detail#201, Accident_Index#195, Latitude#203, Accident_Date_Parsed#220, Longitude#207, Month#197, Local_Authority_(District)#205, Accident_Severity#202, Light_Conditions#204, Time#219, Carriageway_Hazards#206, Urban_or_Rural_Area#215, Weather_Conditions#216, Time_of_Day#221, Speed_limit#213]
#                   +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#211, Road_Type#212, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217, Accident_Date_Parsed#220, date_format(cast(Time#219 as timestamp), HH:mm:ss, Some(Africa/Johannesburg)) AS Time_of_Day#221]
#                      +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#211, Road_Type#212, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217, to_date(Accident Date#196, Some(M/d/yyyy), Some(Africa/Johannesburg), true) AS Accident_Date_Parsed#220]
#                         +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#211, Road_Type#212, Speed_limit#213, cast(Time#214 as string) AS Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217]
#                            +- Relation [Accident_Index#195,Accident Date#196,Month#197,Day_of_Week#198,Year#199,Junction_Control#200,Junction_Detail#201,Accident_Severity#202,Latitude#203,Light_Conditions#204,Local_Authority_(District)#205,Carriageway_Hazards#206,Longitude#207,Number_of_Casualties#208,Number_of_Vehicles#209,Police_Force#210,Road_Surface_Conditions#211,Road_Type#212,Speed_limit#213,Time#214,Urban_or_Rural_Area#215,Weather_Conditions#216,Vehicle_Type#217] csv
#
# == Optimized Logical Plan ==
# Aggregate [Day_of_Week#198, Police_Force#210, Vehicle_Type#217, Road_Type#212, Junction_Control#200, Number_of_Vehicles#209, Number_of_Casualties#208, Year#199, Accident Date#196, Road_Surface_Conditions#211, Junction_Detail#201, Accident_Index#195, Latitude#203, Accident_Date_Parsed#220, Longitude#207, Month#197, Local_Authority_(District)#205, Accident_Severity#202, Light_Conditions#204, Time#219, Carriageway_Hazards#206, Urban_or_Rural_Area#215, Weather_Conditions#216, Time_of_Day#221, Speed_limit#213], [Accident_Index#195, Speed_limit#213]
# +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#211, Road_Type#212, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217, Accident_Date_Parsed#220, date_format(cast(Time#219 as timestamp), HH:mm:ss, Some(Africa/Johannesburg)) AS Time_of_Day#221]
#    +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#211, Road_Type#212, Speed_limit#213, cast(Time#214 as string) AS Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217, cast(gettimestamp(Accident Date#196, M/d/yyyy, TimestampType, try_to_date, Some(Africa/Johannesburg), true) as date) AS Accident_Date_Parsed#220]
#       +- Filter ((isnotnull(Time#214) AND isnotnull(Speed_limit#213)) AND (isnotnull(cast(Time#214 as string)) AND (Speed_limit#213 > 30)))
#          +- Relation [Accident_Index#195,Accident Date#196,Month#197,Day_of_Week#198,Year#199,Junction_Control#200,Junction_Detail#201,Accident_Severity#202,Latitude#203,Light_Conditions#204,Local_Authority_(District)#205,Carriageway_Hazards#206,Longitude#207,Number_of_Casualties#208,Number_of_Vehicles#209,Police_Force#210,Road_Surface_Conditions#211,Road_Type#212,Speed_limit#213,Time#214,Urban_or_Rural_Area#215,Weather_Conditions#216,Vehicle_Type#217] csv
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- HashAggregate(keys=[Day_of_Week#198, Police_Force#210, Vehicle_Type#217, Road_Type#212, Junction_Control#200, Number_of_Vehicles#209, Number_of_Casualties#208, Year#199, Accident Date#196, Road_Surface_Conditions#211, Junction_Detail#201, Accident_Index#195, Latitude#203, Accident_Date_Parsed#220, Longitude#207, Month#197, Local_Authority_(District)#205, Accident_Severity#202, Light_Conditions#204, Time#219, Carriageway_Hazards#206, Urban_or_Rural_Area#215, Weather_Conditions#216, Time_of_Day#221, Speed_limit#213], functions=[], output=[Accident_Index#195, Speed_limit#213])
#    +- Exchange hashpartitioning(Day_of_Week#198, Police_Force#210, Vehicle_Type#217, Road_Type#212, Junction_Control#200, Number_of_Vehicles#209, Number_of_Casualties#208, Year#199, Accident Date#196, Road_Surface_Conditions#211, Junction_Detail#201, Accident_Index#195, Latitude#203, Accident_Date_Parsed#220, Longitude#207, Month#197, Local_Authority_(District)#205, Accident_Severity#202, Light_Conditions#204, Time#219, Carriageway_Hazards#206, Urban_or_Rural_Area#215, Weather_Conditions#216, Time_of_Day#221, Speed_limit#213, ... 1 more fields), ENSURE_REQUIREMENTS, [plan_id=5791]
#       +- HashAggregate(keys=[Day_of_Week#198, Police_Force#210, Vehicle_Type#217, Road_Type#212, Junction_Control#200, Number_of_Vehicles#209, Number_of_Casualties#208, Year#199, Accident Date#196, Road_Surface_Conditions#211, Junction_Detail#201, Accident_Index#195, knownfloatingpointnormalized(normalizenanandzero(Latitude#203)) AS Latitude#203, Accident_Date_Parsed#220, knownfloatingpointnormalized(normalizenanandzero(Longitude#207)) AS Longitude#207, Month#197, Local_Authority_(District)#205, Accident_Severity#202, Light_Conditions#204, Time#219, Carriageway_Hazards#206, Urban_or_Rural_Area#215, Weather_Conditions#216, Time_of_Day#221, Speed_limit#213], functions=[], output=[Day_of_Week#198, Police_Force#210, Vehicle_Type#217, Road_Type#212, Junction_Control#200, Number_of_Vehicles#209, Number_of_Casualties#208, Year#199, Accident Date#196, Road_Surface_Conditions#211, Junction_Detail#201, Accident_Index#195, Latitude#203, Accident_Date_Parsed#220, Longitude#207, Month#197, Local_Authority_(District)#205, Accident_Severity#202, Light_Conditions#204, Time#219, Carriageway_Hazards#206, Urban_or_Rural_Area#215, Weather_Conditions#216, Time_of_Day#221, Speed_limit#213])
#          +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#211, Road_Type#212, Speed_limit#213, Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217, Accident_Date_Parsed#220, date_format(cast(Time#219 as timestamp), HH:mm:ss, Some(Africa/Johannesburg)) AS Time_of_Day#221]
#             +- Project [Accident_Index#195, Accident Date#196, Month#197, Day_of_Week#198, Year#199, Junction_Control#200, Junction_Detail#201, Accident_Severity#202, Latitude#203, Light_Conditions#204, Local_Authority_(District)#205, Carriageway_Hazards#206, Longitude#207, Number_of_Casualties#208, Number_of_Vehicles#209, Police_Force#210, Road_Surface_Conditions#211, Road_Type#212, Speed_limit#213, cast(Time#214 as string) AS Time#219, Urban_or_Rural_Area#215, Weather_Conditions#216, Vehicle_Type#217, cast(gettimestamp(Accident Date#196, M/d/yyyy, TimestampType, try_to_date, Some(Africa/Johannesburg), true) as date) AS Accident_Date_Parsed#220]
#                +- Filter (((isnotnull(Time#214) AND isnotnull(Speed_limit#213)) AND isnotnull(cast(Time#214 as string))) AND (Speed_limit#213 > 30))
#                   +- FileScan csv [Accident_Index#195,Accident Date#196,Month#197,Day_of_Week#198,Year#199,Junction_Control#200,Junction_Detail#201,Accident_Severity#202,Latitude#203,Light_Conditions#204,Local_Authority_(District)#205,Carriageway_Hazards#206,Longitude#207,Number_of_Casualties#208,Number_of_Vehicles#209,Police_Force#210,Road_Surface_Conditions#211,Road_Type#212,Speed_limit#213,Time#214,Urban_or_Rural_Area#215,Weather_Conditions#216,Vehicle_Type#217] Batched: false, DataFilters: [isnotnull(Time#214), isnotnull(Speed_limit#213), isnotnull(cast(Time#214 as string)), (Speed_lim..., Format: CSV, Location: InMemoryFileIndex(1 paths)[hdfs://localhost:9000/rrsis/data/Road Accident Data.csv], PartitionFilters: [], PushedFilters: [IsNotNull(Time), IsNotNull(Speed_limit), GreaterThan(Speed_limit,30)], ReadSchema: struct<Accident_Index:string,Accident Date:string,Month:string,Day_of_Week:string,Year:int,Juncti...

# %%
import time

# Without cache — df_severity gets recomputed from scratch every action
start = time.time()
df_severity.groupBy("Time_Period").count().collect()
df_severity.groupBy("Road_Type").count().collect()
print("Without cache:", time.time() - start, "seconds")

# With cache
df_severity_cached = df_severity.cache()
df_severity_cached.count()  # materializes the cache

start = time.time()
df_severity_cached.groupBy("Time_Period").count().collect()
df_severity_cached.groupBy("Road_Type").count().collect()
print("With cache:", time.time() - start, "seconds")
# Out:
# Without cache: 3.758251190185547 seconds
# With cache: 5.074010610580444 seconds
